# %% [markdown]
# 📊 CIS 9660 – Pandas Class Exercise
#
# <small>📘 Topics Covered:</small>
# <small>1️⃣ Importing libraries</small>
# <small>2️⃣ Creating a DataFrame from a dictionary</small>
# <small>3️⃣ Viewing the first and last rows of the DataFrame</small>
# <small>4️⃣ Checking the number of rows and columns</small>
# <small>5️⃣ Sorting data by column values (ascending & descending)</small>
# <small>6️⃣ Sorting by index (axis=0 & axis=1)</small>
# <small>7️⃣ Slicing the DataFrame</small>
# <small>8️⃣ Creating and displaying a list of fruits</small>
# <small>9️⃣ Filtering data using boolean masks</small>
# <small>🔁 Reversing filters using the tilde <code>~</code> operator</small>
# <small>🔢 Generating basic plots using pandas</small>
# <small>➕ Adding two DataFrames and resetting index</small>
# <small>🛠️ Modifying the index (temporary & permanent)</small>
# <small>🔍 Accessing data using <code>loc[]</code> and <code>iloc[]</code></small>
# <small>♻️ Resetting the index to default</small>
# <small>🎯 Filtering with multiple conditions (e.g., major, age, CGPA)</small>
# <small>🔗 Merging DataFrames (left & right join, SQL-style)</small>

# %%
# 📚 Importing Required Libraries
import pandas as pd                      # For data manipulation and analysis
from tabulate import tabulate            # For nicely formatted table display (optional)
import matplotlib.pyplot as plt          # For data visualization (if needed)

# 🧱 Creating a Pandas DataFrame from a Dictionary

roster = {
    'Name': ['Alice', 'Bob', 'Cathy', 'Dan', 'Eva', 'Frank', 'Grace', 'Hank','Ivy', 'Jack', 'Karen', 'Leo', 'Mona', 'Nate', 'Olivia', 'Paul',
        'Quinn', 'Rose', 'Steve', 'Tina'],
    'Major': ['Finance', 'Accounting', 'Biology', 'Engineering', 'Art','History', 'Physics', 'Math', 'Chemistry', 'Psychology',
              'Marketing', 'CS', 'Philosophy', 'Sociology', 'Music', 'Law','Economics', 'Geology', 'English', 'Stats'],
    'CGPA': [3.8, 3.5, 3.6, 3.9, 3.3, 3.4, 3.7, 3.1, 3.2, 3.85,3.6, 3.95, 3.0, 3.45, 3.75, 3.88, 3.55, 3.35, 3.25, 3.5],
    'Age': [22, 21, 23, 24, 32, 25, 26, 23, 51, 24,22, 37, 30, 25, 23, 24, 16, 22, 21, 23],
    'Gender': ['F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M','F', 'M', 'F', 'M', 'F', 'M', 'F', 'F', 'M', 'F'],
    'Graduated': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'No', 'Yes','Yes', 'Yes', 'Yes', 'Yes', 'Yes',
                  'No', 'No', 'Yes', 'No', 'No'],
    'Credits': [120, 115, 130, 140, 110, 100, 135, 125, 118, 122,119, 138, 105, 127, 131, 133, 121, 117, 116, 129],
    'Country': ['USA', 'Canada', 'USA', 'India', 'UK', 'USA', 'Germany', 'USA', 'India', 'Canada','UK', 'USA', 'Germany',
                'USA', 'India', 'Canada', 'UK', 'USA', 'USA', 'India']
        }
# 🔄 Converting Dictionary to Pandas DataFrame
roster_df_1 = pd.DataFrame(roster)
print(tabulate(roster_df_1, headers='keys', tablefmt='grid'))

# 🔍 Checking the Shape of the DataFrame, column and row
print()
print(f'Number of column and rows')
print('='*50)
print(f"The number of rows and column are {roster_df_1.shape}")
print(f'Which represents 20 rows and 8 column')
# Out:
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |    | Name   | Major       |   CGPA |   Age | Gender   | Graduated   |   Credits | Country   |
# +====+========+=============+========+=======+==========+=============+===========+===========+
# |  0 | Alice  | Finance     |   3.8  |    22 | F        | Yes         |       120 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  1 | Bob    | Accounting  |   3.5  |    21 | M        | Yes         |       115 | Canada    |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  2 | Cathy  | Biology     |   3.6  |    23 | F        | No          |       130 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  3 | Dan    | Engineering |   3.9  |    24 | M        | Yes         |       140 | India     |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  4 | Eva    | Art         |   3.3  |    32 | F        | No          |       110 | UK        |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  5 | Frank  | History     |   3.4  |    25 | M        | Yes         |       100 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  6 | Grace  | Physics     |   3.7  |    26 | F        | No          |       135 | Germany   |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  7 | Hank   | Math        |   3.1  |    23 | M        | No          |       125 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  8 | Ivy    | Chemistry   |   3.2  |    51 | F        | No          |       118 | India     |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# |  9 | Jack   | Psychology  |   3.85 |    24 | M        | Yes         |       122 | Canada    |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 10 | Karen  | Marketing   |   3.6  |    22 | F        | Yes         |       119 | UK        |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 11 | Leo    | CS          |   3.95 |    37 | M        | Yes         |       138 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 12 | Mona   | Philosophy  |   3    |    30 | F        | Yes         |       105 | Germany   |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 13 | Nate   | Sociology   |   3.45 |    25 | M        | Yes         |       127 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 14 | Olivia | Music       |   3.75 |    23 | F        | Yes         |       131 | India     |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 15 | Paul   | Law         |   3.88 |    24 | M        | No          |       133 | Canada    |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 16 | Quinn  | Economics   |   3.55 |    16 | F        | No          |       121 | UK        |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 17 | Rose   | Geology     |   3.35 |    22 | F        | Yes         |       117 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 18 | Steve  | English     |   3.25 |    21 | M        | No          |       116 | USA       |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
# | 19 | Tina   | Stats       |   3.5  |    23 | F        | No          |       129 | India     |
# +----+--------+-------------+--------+-------+----------+-------------+-----------+-----------+
#
# Number of column and rows
# ==================================================
# The number of rows and column are (20, 8)
# Which represents 20 rows and 8 column

# %% [markdown]
# 👀 Viewing the First Rows of the DataFrame
#
# <small>1️⃣ Default view – displays the first 5 rows</small>
# <small>2️⃣ Display only the first 2 rows</small>

# %%
print(roster_df_1.head()) # as default it will select first 5 rows
print('='*50)
print(roster_df_1.head(2)) # head(n) returns first "n" rows from the data set
# Out:
#     Name        Major  CGPA  Age Gender Graduated  Credits Country
# 0  Alice      Finance   3.8   22      F       Yes      120     USA
# 1    Bob   Accounting   3.5   21      M       Yes      115  Canada
# 2  Cathy      Biology   3.6   23      F        No      130     USA
# 3    Dan  Engineering   3.9   24      M       Yes      140   India
# 4    Eva          Art   3.3   32      F        No      110      UK
# ==================================================
#     Name       Major  CGPA  Age Gender Graduated  Credits Country
# 0  Alice     Finance   3.8   22      F       Yes      120     USA
# 1    Bob  Accounting   3.5   21      M       Yes      115  Canada

# %% [markdown]
# 🔽 Selecting the Last Rows of the DataFrame
#
# <small>1️⃣ Default – displays the last 5 rows</small>
# <small>2️⃣ Display only the last 2 rows</small>

# %%
print(roster_df_1.tail()) # as default it will select last 5 rows
print('='*50)
print(roster_df_1.tail(2)) # head(n) returns first "n" rows from the data set
# Out:
#      Name      Major  CGPA  Age Gender Graduated  Credits Country
# 15   Paul        Law  3.88   24      M        No      133  Canada
# 16  Quinn  Economics  3.55   16      F        No      121      UK
# 17   Rose    Geology  3.35   22      F       Yes      117     USA
# 18  Steve    English  3.25   21      M        No      116     USA
# 19   Tina      Stats  3.50   23      F        No      129   India
# ==================================================
#      Name    Major  CGPA  Age Gender Graduated  Credits Country
# 18  Steve  English  3.25   21      M        No      116     USA
# 19   Tina    Stats  3.50   23      F        No      129   India

# %% [markdown]
# 🔢 Sorting the Data by Column Values
#
# <small>1️⃣ Sort by a column in ascending order (default)</small>
# <small>2️⃣ Sort by a column in descending order</small>

# %%
# sorting the cloumn Age as ascending order
print(roster_df_1.sort_values(by = 'Age'))
print('=' * 75)
# sorting the cloumn Age as ascending order
print(roster_df_1.sort_values(by = 'Age', ascending=False))
# Out:
#       Name        Major  CGPA  Age Gender Graduated  Credits  Country
# 16   Quinn    Economics  3.55   16      F        No      121       UK
# 1      Bob   Accounting  3.50   21      M       Yes      115   Canada
# 18   Steve      English  3.25   21      M        No      116      USA
# 0    Alice      Finance  3.80   22      F       Yes      120      USA
# 10   Karen    Marketing  3.60   22      F       Yes      119       UK
# 17    Rose      Geology  3.35   22      F       Yes      117      USA
# 14  Olivia        Music  3.75   23      F       Yes      131    India
# 2    Cathy      Biology  3.60   23      F        No      130      USA
# 19    Tina        Stats  3.50   23      F        No      129    India
# 7     Hank         Math  3.10   23      M        No      125      USA
# 3      Dan  Engineering  3.90   24      M       Yes      140    India
# 15    Paul          Law  3.88   24      M        No      133   Canada
# 9     Jack   Psychology  3.85   24      M       Yes      122   Canada
# 13    Nate    Sociology  3.45   25      M       Yes      127      USA
# 5    Frank      History  3.40   25      M       Yes      100      USA
# 6    Grace      Physics  3.70   26      F        No      135  Germany
# 12    Mona   Philosophy  3.00   30      F       Yes      105  Germany
# 4      Eva          Art  3.30   32      F        No      110       UK
# 11     Leo           CS  3.95   37      M       Yes      138      USA
# 8      Ivy    Chemistry  3.20   51      F        No      118    India
# ===========================================================================
#       Name        Major  CGPA  Age Gender Graduated  Credits  Country
# 8      Ivy    Chemistry  3.20   51      F        No      118    India
# 11     Leo           CS  3.95   37      M       Yes      138      USA
# 4      Eva          Art  3.30   32      F        No      110       UK
# 12    Mona   Philosophy  3.00   30      F       Yes      105  Germany
# 6    Grace      Physics  3.70   26      F        No      135  Germany
# 5    Frank      History  3.40   25      M       Yes      100      USA
# 13    Nate    Sociology  3.45   25      M       Yes      127      USA
# 3      Dan  Engineering  3.90   24      M       Yes      140    India
# 15    Paul          Law  3.88   24      M        No      133   Canada
# 9     Jack   Psychology  3.85   24      M       Yes      122   Canada
# 2    Cathy      Biology  3.60   23      F        No      130      USA
# 7     Hank         Math  3.10   23      M        No      125      USA
# 19    Tina        Stats  3.50   23      F        No      129    India
# 14  Olivia        Music  3.75   23      F       Yes      131    India
# 10   Karen    Marketing  3.60   22      F       Yes      119       UK
# 0    Alice      Finance  3.80   22      F       Yes      120      USA
# 17    Rose      Geology  3.35   22      F       Yes      117      USA
# 1      Bob   Accounting  3.50   21      M       Yes      115   Canada
# 18   Steve      English  3.25   21      M        No      116      USA
# 16   Quinn    Economics  3.55   16      F        No      121       UK

# %% [markdown]
# 🗂️ Sorting the DataFrame by Index
#
# <small>1️⃣ With <code>axis=0</code>, the row index is sorted in descending order.</small>
# <small>2️⃣ With <code>axis=1</code>, the columns are sorted alphabetically — useful for large datasets to view structure at a glance.</small>

# %%
print(roster_df_1.sort_index(axis = 0, ascending=False))
print('='*75)
print(roster_df_1.sort_index(axis = 1, ascending=True))
# Out:
#       Name        Major  CGPA  Age Gender Graduated  Credits  Country
# 19    Tina        Stats  3.50   23      F        No      129    India
# 18   Steve      English  3.25   21      M        No      116      USA
# 17    Rose      Geology  3.35   22      F       Yes      117      USA
# 16   Quinn    Economics  3.55   16      F        No      121       UK
# 15    Paul          Law  3.88   24      M        No      133   Canada
# 14  Olivia        Music  3.75   23      F       Yes      131    India
# 13    Nate    Sociology  3.45   25      M       Yes      127      USA
# 12    Mona   Philosophy  3.00   30      F       Yes      105  Germany
# 11     Leo           CS  3.95   37      M       Yes      138      USA
# 10   Karen    Marketing  3.60   22      F       Yes      119       UK
# 9     Jack   Psychology  3.85   24      M       Yes      122   Canada
# 8      Ivy    Chemistry  3.20   51      F        No      118    India
# 7     Hank         Math  3.10   23      M        No      125      USA
# 6    Grace      Physics  3.70   26      F        No      135  Germany
# 5    Frank      History  3.40   25      M       Yes      100      USA
# 4      Eva          Art  3.30   32      F        No      110       UK
# 3      Dan  Engineering  3.90   24      M       Yes      140    India
# 2    Cathy      Biology  3.60   23      F        No      130      USA
# 1      Bob   Accounting  3.50   21      M       Yes      115   Canada
# 0    Alice      Finance  3.80   22      F       Yes      120      USA
# ===========================================================================
#     Age  CGPA  Country  Credits Gender Graduated        Major    Name
# 0    22  3.80      USA      120      F       Yes      Finance   Alice
# 1    21  3.50   Canada      115      M       Yes   Accounting     Bob
# 2    23  3.60      USA      130      F        No      Biology   Cathy
# 3    24  3.90    India      140      M       Yes  Engineering     Dan
# 4    32  3.30       UK      110      F        No          Art     Eva
# 5    25  3.40      USA      100      M       Yes      History   Frank
# 6    26  3.70  Germany      135      F        No      Physics   Grace
# 7    23  3.10      USA      125      M        No         Math    Hank
# 8    51  3.20    India      118      F        No    Chemistry     Ivy
# 9    24  3.85   Canada      122      M       Yes   Psychology    Jack
# 10   22  3.60       UK      119      F       Yes    Marketing   Karen
# 11   37  3.95      USA      138      M       Yes           CS     Leo
# 12   30  3.00  Germany      105      F       Yes   Philosophy    Mona
# 13   25  3.45      USA      127      M       Yes    Sociology    Nate
# 14   23  3.75    India      131      F       Yes        Music  Olivia
# 15   24  3.88   Canada      133      M        No          Law    Paul
# 16   16  3.55       UK      121      F        No    Economics   Quinn
# 17   22  3.35      USA      117      F       Yes      Geology    Rose
# 18   21  3.25      USA      116      M        No      English   Steve
# 19   23  3.50    India      129      F        No        Stats    Tina

# %% [markdown]
# <small>✂️ Slicing the DataFrame</small>

# %%
# List
fruit = ['Mango', 'Strawberry', 'Blueberry', 'Watermelon', 'Kiwi','Papaya', 'Peach', 'Cherry', 'Lemon', 'Coconut']

print(fruit[2:5]) # ['Blueberry', 'Watermelon', 'Kiwi'],start from 2 and ends with 4.
print(fruit[4:]) # ['Kiwi','Papaya', 'Peach', 'Cherry', 'Lemon', 'Coconut'],start from 4 and to the end.
print(fruit[:5]) # ['Mango', 'Strawberry', 'Blueberry', 'Watermelon', 'Kiwi'],start from 0 and ends on 4. Slicing start from left.
print(fruit[-2:-6]) # [],start from -2 ('Lemon') and stop before -6 ('Kiwi'). But Slicing start from left, so [].
print(fruit[-2:-3]) # [],start from -2 ('Lemon') and stop before -3 ('Cherry'). But Slicing start from left, so [].
print(fruit[-8:-4]) # ['Blueberry','Watermelon', 'Kiwi','Papaya'] Start from -8 ('Blueberry')c, stop before -4 ('Peach').
print(fruit[:-4]) # ['Mango', 'Strawberry', 'Blueberry', 'Watermelon', 'Kiwi','Papaya']
# Out:
# ['Blueberry', 'Watermelon', 'Kiwi']
# ['Kiwi', 'Papaya', 'Peach', 'Cherry', 'Lemon', 'Coconut']
# ['Mango', 'Strawberry', 'Blueberry', 'Watermelon', 'Kiwi']
# []
# []
# ['Blueberry', 'Watermelon', 'Kiwi', 'Papaya']
# ['Mango', 'Strawberry', 'Blueberry', 'Watermelon', 'Kiwi', 'Papaya']

# %% [markdown]
# ✂️ Slicing the DataFrame
#
# <small>Use slicing to select a specific range of rows or columns from the DataFrame.</small>
# <small>Syntax: <code>df[start:stop]</code> — returns rows from index <code>start</code> to <code>stop </code>.</small>

# %%
print(roster_df_1[2:5])
print('='*75)
print(roster_df_1[4:])
print('='*75)
print(roster_df_1[:5])
print('='*75)
print(roster_df_1[-2:-6])
print('='*75)
print(roster_df_1[-2:-3])
print('='*75)
print(roster_df_1[-8:-4])
print('='*75)
print(roster_df_1[:-4])
# Out:
#     Name        Major  CGPA  Age Gender Graduated  Credits Country
# 2  Cathy      Biology   3.6   23      F        No      130     USA
# 3    Dan  Engineering   3.9   24      M       Yes      140   India
# 4    Eva          Art   3.3   32      F        No      110      UK
# ===========================================================================
#       Name       Major  CGPA  Age Gender Graduated  Credits  Country
# 4      Eva         Art  3.30   32      F        No      110       UK
# 5    Frank     History  3.40   25      M       Yes      100      USA
# 6    Grace     Physics  3.70   26      F        No      135  Germany
# 7     Hank        Math  3.10   23      M        No      125      USA
# 8      Ivy   Chemistry  3.20   51      F        No      118    India
# 9     Jack  Psychology  3.85   24      M       Yes      122   Canada
# 10   Karen   Marketing  3.60   22      F       Yes      119       UK
# 11     Leo          CS  3.95   37      M       Yes      138      USA
# 12    Mona  Philosophy  3.00   30      F       Yes      105  Germany
# 13    Nate   Sociology  3.45   25      M       Yes      127      USA
# 14  Olivia       Music  3.75   23      F       Yes      131    India
# 15    Paul         Law  3.88   24      M        No      133   Canada
# 16   Quinn   Economics  3.55   16      F        No      121       UK
# 17    Rose     Geology  3.35   22      F       Yes      117      USA
# 18   Steve     English  3.25   21      M        No      116      USA
# 19    Tina       Stats  3.50   23      F        No      129    India
# ===========================================================================
#     Name        Major  CGPA  Age Gender Graduated  Credits Country
# 0  Alice      Finance   3.8   22      F       Yes      120     USA
# 1    Bob   Accounting   3.5   21      M       Yes      115  Canada
# 2  Cathy      Biology   3.6   23      F        No      130     USA
# 3    Dan  Engineering   3.9   24      M       Yes      140   India
# 4    Eva          Art   3.3   32      F        No      110      UK
# ===========================================================================
# Empty DataFrame
# Columns: [Name, Major, CGPA, Age, Gender, Graduated, Credits, Country]
# Index: []
# ===========================================================================
# Empty DataFrame
# Columns: [Name, Major, CGPA, Age, Gender, Graduated, Credits, Country]
# Index: []
# ===========================================================================
#       Name       Major  CGPA  Age Gender Graduated  Credits  Country
# 12    Mona  Philosophy  3.00   30      F       Yes      105  Germany
# 13    Nate   Sociology  3.45   25      M       Yes      127      USA
# 14  Olivia       Music  3.75   23      F       Yes      131    India
# 15    Paul         Law  3.88   24      M        No      133   Canada
# ===========================================================================
#       Name        Major  CGPA  Age Gender Graduated  Credits  Country
# 0    Alice      Finance  3.80   22      F       Yes      120      USA
# 1      Bob   Accounting  3.50   21      M       Yes      115   Canada
# 2    Cathy      Biology  3.60   23      F        No      130      USA
# 3      Dan  Engineering  3.90   24      M       Yes      140    India
# 4      Eva          Art  3.30   32      F        No      110       UK
# 5    Frank      History  3.40   25      M       Yes      100      USA
# 6    Grace      Physics  3.70   26      F        No      135  Germany
# 7     Hank         Math  3.10   23      M        No      125      USA
# 8      Ivy    Chemistry  3.20   51      F        No      118    India
# 9     Jack   Psychology  3.85   24      M       Yes      122   Canada
# 10   Karen    Marketing  3.60   22      F       Yes      119       UK
# 11     Leo           CS  3.95   37      M       Yes      138      USA
# 12    Mona   Philosophy  3.00   30      F       Yes      105  Germany
# 13    Nate    Sociology  3.45   25      M       Yes      127      USA
# 14  Olivia        Music  3.75   23      F       Yes      131    India
# 15    Paul          Law  3.88   24      M        No      133   Canada

# %% [markdown]
# 🔎 Filtering Values from the DataFrame Using a Mask
#
# <small>1️⃣ Filter by <code>CGPA</code></small>
# <small>2️⃣ Filter by <code>Age</code></small>
# <small>3️⃣ Filter by <code>Country</code></small>
# <small>4️⃣ Combine multiple filters in one command using filter mask</small>

# %%
# Define filter masks with meaningful names
high_cgpa_mask = roster_df_1['CGPA'] > 3.85
age_above_35_mask = roster_df_1['Age'] > 35
country_usa_mask = roster_df_1['Country'] == 'USA'
filter_mask = high_cgpa_mask & age_above_35_mask & country_usa_mask

# Apply filters and print results with clear section titles
print("🎓 Students with CGPA > 3.85")
print(roster_df_1[high_cgpa_mask])
print("=" * 75)

print("🧓 Students with Age > 35")
print(roster_df_1[age_above_35_mask])
print("=" * 75)

print("🌎 Students from the USA")
print(roster_df_1[country_usa_mask])
print("=" * 75)

print("🌎 Students from the USA, 🧓age over 35 and 🎓higher CGPA")
print(roster_df_1[filter_mask]) # Same thing can be done with df.loc[filter_mask]
# Out:
# 🎓 Students with CGPA > 3.85
#     Name        Major  CGPA  Age Gender Graduated  Credits Country
# 3    Dan  Engineering  3.90   24      M       Yes      140   India
# 11   Leo           CS  3.95   37      M       Yes      138     USA
# 15  Paul          Law  3.88   24      M        No      133  Canada
# ===========================================================================
# 🧓 Students with Age > 35
#    Name      Major  CGPA  Age Gender Graduated  Credits Country
# 8   Ivy  Chemistry  3.20   51      F        No      118   India
# 11  Leo         CS  3.95   37      M       Yes      138     USA
# ===========================================================================
# 🌎 Students from the USA
#      Name      Major  CGPA  Age Gender Graduated  Credits Country
# 0   Alice    Finance  3.80   22      F       Yes      120     USA
# 2   Cathy    Biology  3.60   23      F        No      130     USA
# 5   Frank    History  3.40   25      M       Yes      100     USA
# 7    Hank       Math  3.10   23      M        No      125     USA
# 11    Leo         CS  3.95   37      M       Yes      138     USA
# 13   Nate  Sociology  3.45   25      M       Yes      127     USA
# 17   Rose    Geology  3.35   22      F       Yes      117     USA
# 18  Steve    English  3.25   21      M        No      116     USA
# ===========================================================================
# 🌎 Students from the USA, 🧓age over 35 and 🎓higher CGPA
#    Name Major  CGPA  Age Gender Graduated  Credits Country
# 11  Leo    CS  3.95   37      M       Yes      138     USA

# %% [markdown]
# <small>🔁 Using Tilde <code>(~)</code> for Reverse Filtering</small>

# %%
print("🌎 Students not 🎓higher CGPA")
print(roster_df_1[~high_cgpa_mask]) # ~ (tilde) do the opposite
# Out:
# 🌎 Students not 🎓higher CGPA
#       Name       Major  CGPA  Age Gender Graduated  Credits  Country
# 0    Alice     Finance  3.80   22      F       Yes      120      USA
# 1      Bob  Accounting  3.50   21      M       Yes      115   Canada
# 2    Cathy     Biology  3.60   23      F        No      130      USA
# 4      Eva         Art  3.30   32      F        No      110       UK
# 5    Frank     History  3.40   25      M       Yes      100      USA
# 6    Grace     Physics  3.70   26      F        No      135  Germany
# 7     Hank        Math  3.10   23      M        No      125      USA
# 8      Ivy   Chemistry  3.20   51      F        No      118    India
# 9     Jack  Psychology  3.85   24      M       Yes      122   Canada
# 10   Karen   Marketing  3.60   22      F       Yes      119       UK
# 12    Mona  Philosophy  3.00   30      F       Yes      105  Germany
# 13    Nate   Sociology  3.45   25      M       Yes      127      USA
# 14  Olivia       Music  3.75   23      F       Yes      131    India
# 16   Quinn   Economics  3.55   16      F        No      121       UK
# 17    Rose     Geology  3.35   22      F       Yes      117      USA
# 18   Steve     English  3.25   21      M        No      116      USA
# 19    Tina       Stats  3.50   23      F        No      129    India

# %% [markdown]
# 📊 Generating Charts Using Pandas
#
# <small>1️⃣ Scatter plot DataFrame columns</small>

# %%
# library matplotlib.pyplot as plt imported

roster_df_1.plot(x = 'CGPA', y = 'Age', kind ='scatter')
plt.title ('CGPA Vs Age')
plt.show()

# %%
NewDf = roster_df_1.drop(columns=['Name', 'Major','Gender','Graduated','Country'])
print(NewDf.corr())
# Out:
#              CGPA       Age   Credits
# CGPA     1.000000 -0.198886  0.678533
# Age     -0.198886  1.000000 -0.045194
# Credits  0.678533 -0.045194  1.000000

# %%
# Creating new DataFrame

roster_df_2 = {
    'Name': ['Zara', 'Liam', 'Noah', 'Mia', 'Aria', 'Ethan'],
    'Major': ['Robotics', 'Finance', 'Finance', 'Finance', 'Finance', 'Marine Biology'],
    'CGPA': [3.92, 3.75, 3.30, 3.88, 3.65, 3.45],
    'Age': [23, 24, 27, 22, 21, 28],
    'Gender': ['F', 'M', 'M', 'F', 'F', 'M'],
    'Graduated': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
    'Credits': [128, 119, 110, 123, 132, 108],
    'Country': ['USA', 'Canada', 'Germany', 'USA', 'UK', 'India']
}
roster_df_2 = pd.DataFrame(roster_df_2)
roster_df_2
# Out:
#     Name           Major  CGPA  Age Gender Graduated  Credits  Country
# 0   Zara        Robotics  3.92   23      F       Yes      128      USA
# 1   Liam         Finance  3.75   24      M        No      119   Canada
# 2   Noah         Finance  3.30   27      M       Yes      110  Germany
# 3    Mia         Finance  3.88   22      F        No      123      USA
# 4   Aria         Finance  3.65   21      F       Yes      132       UK
# 5  Ethan  Marine Biology  3.45   28      M        No      108    India

# %%
# Adding Two DataFrames and fixing the index
Combine_df_1 = pd.concat([roster_df_1, roster_df_2], ignore_index= True)
print(Combine_df_1)
# Out:
#       Name           Major  CGPA  Age Gender Graduated  Credits  Country
# 0    Alice         Finance  3.80   22      F       Yes      120      USA
# 1      Bob      Accounting  3.50   21      M       Yes      115   Canada
# 2    Cathy         Biology  3.60   23      F        No      130      USA
# 3      Dan     Engineering  3.90   24      M       Yes      140    India
# 4      Eva             Art  3.30   32      F        No      110       UK
# 5    Frank         History  3.40   25      M       Yes      100      USA
# 6    Grace         Physics  3.70   26      F        No      135  Germany
# 7     Hank            Math  3.10   23      M        No      125      USA
# 8      Ivy       Chemistry  3.20   51      F        No      118    India
# 9     Jack      Psychology  3.85   24      M       Yes      122   Canada
# 10   Karen       Marketing  3.60   22      F       Yes      119       UK
# 11     Leo              CS  3.95   37      M       Yes      138      USA
# 12    Mona      Philosophy  3.00   30      F       Yes      105  Germany
# 13    Nate       Sociology  3.45   25      M       Yes      127      USA
# 14  Olivia           Music  3.75   23      F       Yes      131    India
# 15    Paul             Law  3.88   24      M        No      133   Canada
# 16   Quinn       Economics  3.55   16      F        No      121       UK
# 17    Rose         Geology  3.35   22      F       Yes      117      USA
# 18   Steve         English  3.25   21      M        No      116      USA
# 19    Tina           Stats  3.50   23      F        No      129    India
# 20    Zara        Robotics  3.92   23      F       Yes      128      USA
# 21    Liam         Finance  3.75   24      M        No      119   Canada
# 22    Noah         Finance  3.30   27      M       Yes      110  Germany
# 23     Mia         Finance  3.88   22      F        No      123      USA
# 24    Aria         Finance  3.65   21      F       Yes      132       UK
# 25   Ethan  Marine Biology  3.45   28      M        No      108    India

# %%
Combine_df_1_horizontal= pd.concat([roster_df_1, roster_df_2], axis = 1)
print(Combine_df_1_horizontal)
# Out:
#       Name        Major  CGPA  Age Gender Graduated  Credits  Country   Name  \
# 0    Alice      Finance  3.80   22      F       Yes      120      USA   Zara
# 1      Bob   Accounting  3.50   21      M       Yes      115   Canada   Liam
# 2    Cathy      Biology  3.60   23      F        No      130      USA   Noah
# 3      Dan  Engineering  3.90   24      M       Yes      140    India    Mia
# 4      Eva          Art  3.30   32      F        No      110       UK   Aria
# 5    Frank      History  3.40   25      M       Yes      100      USA  Ethan
# 6    Grace      Physics  3.70   26      F        No      135  Germany    NaN
# 7     Hank         Math  3.10   23      M        No      125      USA    NaN
# 8      Ivy    Chemistry  3.20   51      F        No      118    India    NaN
# 9     Jack   Psychology  3.85   24      M       Yes      122   Canada    NaN
# 10   Karen    Marketing  3.60   22      F       Yes      119       UK    NaN
# 11     Leo           CS  3.95   37      M       Yes      138      USA    NaN
# 12    Mona   Philosophy  3.00   30      F       Yes      105  Germany    NaN
# 13    Nate    Sociology  3.45   25      M       Yes      127      USA    NaN
# 14  Olivia        Music  3.75   23      F       Yes      131    India    NaN
# 15    Paul          Law  3.88   24      M        No      133   Canada    NaN
# 16   Quinn    Economics  3.55   16      F        No      121       UK    NaN
# 17    Rose      Geology  3.35   22      F       Yes      117      USA    NaN
# 18   Steve      English  3.25   21      M        No      116      USA    NaN
# 19    Tina        Stats  3.50   23      F        No      129    India    NaN
#
#              Major  CGPA   Age Gender Graduated  Credits  Country
# 0         Robotics  3.92  23.0      F       Yes    128.0      USA
# 1          Finance  3.75  24.0      M        No    119.0   Canada
# 2          Finance  3.30  27.0      M       Yes    110.0  Germany
# 3          Finance  3.88  22.0      F        No    123.0      USA
# 4          Finance  3.65  21.0      F       Yes    132.0       UK
# 5   Marine Biology  3.45  28.0      M        No    108.0    India
# 6              NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 7              NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 8              NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 9              NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 10             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 11             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 12             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 13             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 14             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 15             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 16             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 17             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 18             NaN   NaN   NaN    NaN       NaN      NaN      NaN
# 19             NaN   NaN   NaN    NaN       NaN      NaN      NaN

# %%
Combine_df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       26 non-null     object
#  1   Major      26 non-null     object
#  2   CGPA       26 non-null     float64
#  3   Age        26 non-null     int64
#  4   Gender     26 non-null     object
#  5   Graduated  26 non-null     object
#  6   Credits    26 non-null     int64
#  7   Country    26 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.8+ KB

# %% [markdown]
# 🛠️ Modifying the Index of the DataFrame
#
# <small>1️⃣ Modify the index <strong>temporarily</strong> by assigning a new index directly to a copy or during display.</small>
# <small>2️⃣ Modify the index <strong>permanently</strong> using <code>df.set_index()</code> with <code>inplace=True</code>.</small>

# %%
print(Combine_df_1.set_index('Country'))
print('='*75)
print(Combine_df_1.set_index('Country', inplace=True))
# Out:
#            Name           Major  CGPA  Age Gender Graduated  Credits
# Country
# USA       Alice         Finance  3.80   22      F       Yes      120
# Canada      Bob      Accounting  3.50   21      M       Yes      115
# USA       Cathy         Biology  3.60   23      F        No      130
# India       Dan     Engineering  3.90   24      M       Yes      140
# UK          Eva             Art  3.30   32      F        No      110
# USA       Frank         History  3.40   25      M       Yes      100
# Germany   Grace         Physics  3.70   26      F        No      135
# USA        Hank            Math  3.10   23      M        No      125
# India       Ivy       Chemistry  3.20   51      F        No      118
# Canada     Jack      Psychology  3.85   24      M       Yes      122
# UK        Karen       Marketing  3.60   22      F       Yes      119
# USA         Leo              CS  3.95   37      M       Yes      138
# Germany    Mona      Philosophy  3.00   30      F       Yes      105
# USA        Nate       Sociology  3.45   25      M       Yes      127
# India    Olivia           Music  3.75   23      F       Yes      131
# Canada     Paul             Law  3.88   24      M        No      133
# UK        Quinn       Economics  3.55   16      F        No      121
# USA        Rose         Geology  3.35   22      F       Yes      117
# USA       Steve         English  3.25   21      M        No      116
# India      Tina           Stats  3.50   23      F        No      129
# USA        Zara        Robotics  3.92   23      F       Yes      128
# Canada     Liam         Finance  3.75   24      M        No      119
# Germany    Noah         Finance  3.30   27      M       Yes      110
# USA         Mia         Finance  3.88   22      F        No      123
# UK         Aria         Finance  3.65   21      F       Yes      132
# India     Ethan  Marine Biology  3.45   28      M        No      108
# ===========================================================================
# None

# %%
Combine_df_1
# Out:
#            Name           Major  CGPA  Age Gender Graduated  Credits
# Country
# USA       Alice         Finance  3.80   22      F       Yes      120
# Canada      Bob      Accounting  3.50   21      M       Yes      115
# USA       Cathy         Biology  3.60   23      F        No      130
# India       Dan     Engineering  3.90   24      M       Yes      140
# UK          Eva             Art  3.30   32      F        No      110
# USA       Frank         History  3.40   25      M       Yes      100
# Germany   Grace         Physics  3.70   26      F        No      135
# USA        Hank            Math  3.10   23      M        No      125
# India       Ivy       Chemistry  3.20   51      F        No      118
# Canada     Jack      Psychology  3.85   24      M       Yes      122
# UK        Karen       Marketing  3.60   22      F       Yes      119
# USA         Leo              CS  3.95   37      M       Yes      138
# Germany    Mona      Philosophy  3.00   30      F       Yes      105
# USA        Nate       Sociology  3.45   25      M       Yes      127
# India    Olivia           Music  3.75   23      F       Yes      131
# Canada     Paul             Law  3.88   24      M        No      133
# UK        Quinn       Economics  3.55   16      F        No      121
# USA        Rose         Geology  3.35   22      F       Yes      117
# USA       Steve         English  3.25   21      M        No      116
# India      Tina           Stats  3.50   23      F        No      129
# USA        Zara        Robotics  3.92   23      F       Yes      128
# Canada     Liam         Finance  3.75   24      M        No      119
# Germany    Noah         Finance  3.30   27      M       Yes      110
# USA         Mia         Finance  3.88   22      F        No      123
# UK         Aria         Finance  3.65   21      F       Yes      132
# India     Ethan  Marine Biology  3.45   28      M        No      108

# %% [markdown]
# 🔍 Using <code>.loc[]</code> to Access Data by Index

# %%
Combine_df_1.loc['Canada']
# Out:
#          Name       Major  CGPA  Age Gender Graduated  Credits
# Country
# Canada    Bob  Accounting  3.50   21      M       Yes      115
# Canada   Jack  Psychology  3.85   24      M       Yes      122
# Canada   Paul         Law  3.88   24      M        No      133
# Canada   Liam     Finance  3.75   24      M        No      119

# %%
Combine_df_1.loc['Canada', 'CGPA']
# Out:
# Country
# Canada    3.50
# Canada    3.85
# Canada    3.88
# Canada    3.75
# Name: CGPA, dtype: float64

# %% [markdown]
# <small>♻️ Resetting the Index of a DataFrame</small>

# %%
Combine_df_1.reset_index(inplace=True)
print(Combine_df_1)
# Out:
#     index  Country    Name           Major  CGPA  Age Gender Graduated  \
# 0       0      USA   Alice         Finance  3.80   22      F       Yes
# 1       1   Canada     Bob      Accounting  3.50   21      M       Yes
# 2       2      USA   Cathy         Biology  3.60   23      F        No
# 3       3    India     Dan     Engineering  3.90   24      M       Yes
# 4       4       UK     Eva             Art  3.30   32      F        No
# 5       5      USA   Frank         History  3.40   25      M       Yes
# 6       6  Germany   Grace         Physics  3.70   26      F        No
# 7       7      USA    Hank            Math  3.10   23      M        No
# 8       8    India     Ivy       Chemistry  3.20   51      F        No
# 9       9   Canada    Jack      Psychology  3.85   24      M       Yes
# 10     10       UK   Karen       Marketing  3.60   22      F       Yes
# 11     11      USA     Leo              CS  3.95   37      M       Yes
# 12     12  Germany    Mona      Philosophy  3.00   30      F       Yes
# 13     13      USA    Nate       Sociology  3.45   25      M       Yes
# 14     14    India  Olivia           Music  3.75   23      F       Yes
# 15     15   Canada    Paul             Law  3.88   24      M        No
# 16     16       UK   Quinn       Economics  3.55   16      F        No
# 17     17      USA    Rose         Geology  3.35   22      F       Yes
# 18     18      USA   Steve         English  3.25   21      M        No
# 19     19    India    Tina           Stats  3.50   23      F        No
# 20     20      USA    Zara        Robotics  3.92   23      F       Yes
# 21     21   Canada    Liam         Finance  3.75   24      M        No
# 22     22  Germany    Noah         Finance  3.30   27      M       Yes
# 23     23      USA     Mia         Finance  3.88   22      F        No
# 24     24       UK    Aria         Finance  3.65   21      F       Yes
# 25     25    India   Ethan  Marine Biology  3.45   28      M        No
#
#     Credits
# 0       120
# 1       115
# 2       130
# 3       140
# 4       110
# 5       100
# 6       135
# 7       125
# 8       118
# 9       122
# 10      119
# 11      138
# 12      105
# 13      127
# 14      131
# 15      133
# 16      121
# 17      117
# 18      116
# 19      129
# 20      128
# 21      119
# 22      110
# 23      123
# 24      132
# 25      108

# %% [markdown]
# 🎯 Filtering Students by Multiple Conditions
# <small>Select all students who:</small>
# <small>• Have a <strong>finance</strong> major</small>
# <small>• Are older than <strong>20</strong></small>
# <small>• Have a <strong>CGPA</strong> below <strong>3.7</strong></small>

# %%
Lower_CGPA = Combine_df_1['CGPA'] < 3.7
Age_30_above =  Combine_df_1['Age'] > 20
Finance_major= Combine_df_1['Major'] == 'Finance'
FilterMask = Lower_CGPA & Age_30_above & Finance_major

print(Combine_df_1[FilterMask])
# Out:
#     index  Country  Name    Major  CGPA  Age Gender Graduated  Credits
# 22     22  Germany  Noah  Finance  3.30   27      M       Yes      110
# 24     24       UK  Aria  Finance  3.65   21      F       Yes      132

# %% [markdown]
# 🔢 Using <code>.iloc[]</code> to Access Rows by Position
#
# <small>1️⃣ Works similarly to slicing in Python lists — e.g., <code>

# %%
Combine_df_1.iloc[0:5]
# Out:
#   Country   Name        Major  CGPA  Age Gender Graduated  Credits
# 0     USA  Alice      Finance   3.8   22      F       Yes      120
# 1  Canada    Bob   Accounting   3.5   21      M       Yes      115
# 2     USA  Cathy      Biology   3.6   23      F        No      130
# 3   India    Dan  Engineering   3.9   24      M       Yes      140
# 4      UK    Eva          Art   3.3   32      F        No      110

# %% [markdown]
# 🔗 Merging Two DataFrames (Like SQL Joins)
#
# <small>1️⃣ <strong>Left Merge</strong> – returns all records from the left DataFrame and matching ones from the right.</small>
#
# <small>2️⃣ <strong>Right Merge</strong> – returns all records from the right DataFrame and matching ones from the left.</small>

# %%
# Creating two new dataframe with pandas

# dataframe one as dictionary
New_roster = {"emplid": [3421, 4723, 1331, 5435, 9453, 2345, 6234, 6845, 6245, 9645],
          "Name" : ["Bob", "Alice", "Joe", "Mike", "Lisa", "Alan", "Eli", "Mark", "Liz", "Jane"],
          "Major": ["Accounting", "Finance", "Chemistry", "Art", "Engineering", "Biology", "Physics", "History", "Art", "Engineering"],
          "GPA": [3.5, 3.8, 3.2, 3.7, 4.0, 3.5, 3.8, 3.2, 3.1, 3.0],
          "Age": [22, 23, 31, 40, 25, 22, 33, 31, 27, 55]
          }
# convert the dictionary into pandas
roster1_df = pd.DataFrame(New_roster)

# dataframe one as dictionary
address = {"emplid": [3421, 1331, 5435, 2345, 6845, 7425, 4045, 8245],
          "Address" : ["1 Hyland Blvd", "88 Parkside Ave", "848 Jersey Turnpike", "3 Main Street", "231 Water Street", "22 1st Ave", "4 Grand Concourse", "222 William Street"],
          "City": ["Staten Island", "Brooklyn", "Hoboken", "Queens", "New Haven", "Manhattan", "Bronx", "Hempstead"],
          "State": ["NY", "NY", "NJ", "NY", "CT", "NY", "NY", "NY"],
          "Zipcode": [10304, 11220, 70086, 11432, 60511, 10024, 10458, 24231]
          }
# convert the dictionary into pandas
address_df = pd.DataFrame(address)

# Merging (Left) two data frames
results = pd.merge(roster1_df, address_df, how='left', on = ['emplid'])
results
# Out:
#    emplid   Name        Major  GPA  Age              Address           City  \
# 0    3421    Bob   Accounting  3.5   22        1 Hyland Blvd  Staten Island
# 1    4723  Alice      Finance  3.8   23                  NaN            NaN
# 2    1331    Joe    Chemistry  3.2   31      88 Parkside Ave       Brooklyn
# 3    5435   Mike          Art  3.7   40  848 Jersey Turnpike        Hoboken
# 4    9453   Lisa  Engineering  4.0   25                  NaN            NaN
# 5    2345   Alan      Biology  3.5   22        3 Main Street         Queens
# 6    6234    Eli      Physics  3.8   33                  NaN            NaN
# 7    6845   Mark      History  3.2   31     231 Water Street      New Haven
# 8    6245    Liz          Art  3.1   27                  NaN            NaN
# 9    9645   Jane  Engineering  3.0   55                  NaN            NaN
#
#   State  Zipcode
# 0    NY  10304.0
# 1   NaN      NaN
# 2    NY  11220.0
# 3    NJ  70086.0
# 4   NaN      NaN
# 5    NY  11432.0
# 6   NaN      NaN
# 7    CT  60511.0
# 8   NaN      NaN
# 9   NaN      NaN

# %%
# Merging (right) two data frames
results_2 = pd.merge(roster1_df, address_df, how='right', on = ['emplid'])
results_2
# Out:
#    emplid  Name       Major  GPA   Age              Address           City  \
# 0    3421   Bob  Accounting  3.5  22.0        1 Hyland Blvd  Staten Island
# 1    1331   Joe   Chemistry  3.2  31.0      88 Parkside Ave       Brooklyn
# 2    5435  Mike         Art  3.7  40.0  848 Jersey Turnpike        Hoboken
# 3    2345  Alan     Biology  3.5  22.0        3 Main Street         Queens
# 4    6845  Mark     History  3.2  31.0     231 Water Street      New Haven
# 5    7425   NaN         NaN  NaN   NaN           22 1st Ave      Manhattan
# 6    4045   NaN         NaN  NaN   NaN    4 Grand Concourse          Bronx
# 7    8245   NaN         NaN  NaN   NaN   222 William Street      Hempstead
#
#   State  Zipcode
# 0    NY    10304
# 1    NY    11220
# 2    NJ    70086
# 3    NY    11432
# 4    CT    60511
# 5    NY    10024
# 6    NY    10458
# 7    NY    24231
